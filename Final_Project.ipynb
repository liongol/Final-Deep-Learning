# %% [markdown]
# # Final Project
#
# Now that you've been guided which experiment to run in assignment 2, you will be exploring on your own, trying to achieve the best accuracy for cifar10.
#
# In this notebook you will be asked to tune some hyperparameters, while it is recommended to tune additional hyperparameters to achieve high performance.
#
# In addition, you will be asked to read some matirials by yourselves, summeraize some of them, and combine thier innovaitive ideas in your network.
#
# You can use part of the data, in order to speed up the training, however, the **dataset size** you test on should be large. Use at least ~12000 training images and ~3000 validation images. The **batch size** parameter however is also up to you (you can increase it in order to speed up the training).
#
# You can run the experiments from several notebooks, while you save the output files in the results dictionary (choose meaningful names) and use 'plot_exp_results' to plot it.
#
# You may want to use loops in order to automatically run each section's experiments.
#
# You will will submit this notebook, all relevant the python files and a report that summerize your attempts and results. Follow the instructions and answer the question in your report.
#
# It is important to describe the hyperparameters you used, how you chose them, and how they affected your results.

# %% [markdown]
# **In each section write the best train val and test accuracy and loss.**

# %%
# !pip install tqdm==4.17.1
import os
import re
import sys
import glob
import numpy as np
import matplotlib.pyplot as plt
import unittest
import torch
import torchvision
import torchvision.transforms as tvtf
import torch.nn as nn
import torch.optim as optim


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

seed = 42
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

plt.rcParams.update({'font.size': 12})
test = unittest.TestCase()
# Out:
# Requirement already satisfied: tqdm==4.17.1 in c:\users\liong\anaconda3\envs\gpu\lib\site-packages (4.17.1)
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from google.colab import drive
drive.mount('/content/drive') 
#change this
# %cd /content/drive/My\ Drive/... #change this to your drive dict

# %%
from utils import *
from  utils import models
import utils.experiments as experiments
from utils.experiments import load_experiment
from utils.plot import plot_fit
import utils.training as training
torch.manual_seed(seed)

# %%
def plot_exp_results(filename_pattern, results_dir='results'):
    fig = None
    result_files = glob.glob(os.path.join(results_dir, filename_pattern))
    result_files.sort()
    if len(result_files) == 0:
        print(f'No results found for pattern {filename_pattern}.', file=sys.stderr)
        return
    for filepath in result_files:
        m = re.match('exp\d_(\d_)?(.*)\.json', os.path.basename(filepath))
        cfg, fit_res = load_experiment(filepath)
        fig, axes = plot_fit(fit_res, fig, legend=m[2],log_loss=True)
    del cfg['filters_per_layer']
    del cfg['layers_per_block']
    print('common config: ', cfg)

# %% [markdown]
# ## Build Your Own Achitecture

# %%
data_dir = os.path.expanduser('~/.pytorch-datasets')
ds_train = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=True, transform=tvtf.ToTensor())
ds_test = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=False, transform=tvtf.ToTensor())

print(f'Train: {len(ds_train)} samples')
print(f'Test: {len(ds_test)} samples')

x0,_ = ds_train[0]
in_size = x0.shape
num_classes = 10
print('input image size =', in_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train: 50000 samples
# Test: 10000 samples
# input image size = torch.Size([3, 32, 32])

# %% [markdown]
# ### 1. Implement YourCodeNet model
# Implement YourCodeNet model in utiles/models and define the model architecture (use your previouse assignment's insights).
# Define `filters_per_layer`, `layers_per_block` and `hidden_dims` which you believe are the best for this task. You can run some experiments in order to set these hyperparameters.

# %% [markdown]
# To make the experiment runner use your custom network model, remember to set ycn=True when you call experiments.run_experiment(...).

# %%
# Just to see that the model run
net = models.YourCodeNet((3,100,100), 10, filters=[32]*4, pool_every=2, hidden_dims=[100]*2).to(device)
print(net)

test_image = torch.randint(low=0, high=256, size=(3, 100, 100), dtype=torch.float).to(device)
test_out = net(test_image.unsqueeze(0))
print('out =', test_out)
# Out:
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Dropout2d(p=0.2, inplace=False)
#     (3): ReLU()
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Dropout2d(p=0.2, inplace=False)
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Dropout2d(p=0.2, inplace=False)
#     (12): ReLU()
#     (13): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (15): Dropout2d(p=0.2, inplace=False)
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=20000, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Dropout2d(p=0.2, inplace=False)
#     (3): ReLU()
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Dropout2d(p=0.2, inplace=False)
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Dropout2d(p=0.2, inplace=False)
#     (12): ReLU()
#     (13): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (15): Dropout2d(p=0.2, inplace=False)
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=20000, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# out = tensor([[ 0.0068, -0.2392, -0.0836,  0.0371, -0.1491, -0.0450,  0.2170, -0.1717,
#          -0.0054,  0.1539]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
# set ycn=True when you call experiments.run_experiment(...).
# Use meaningful names!
# ====== YOUR CODE: ======
experiment_num = 1
list_filters_per_layer = [[32], [64], [128], [256]]
list_hidden_dims = [[100], [150], [200]]

for layers_per_block in range(1, 4):
    for filter_per_layer in list_filters_per_layer:
        for hidden_dim in list_hidden_dims:
            experiments.run_experiment("exp" + f"{experiment_num}" + "_" + f"{layers_per_block}" + "_" + f"{filter_per_layer}" + "_" + f"{hidden_dim}", seed=seed, bs_train=50, batches=10, epochs=10, early_stopping=5,
                                       filters_per_layer=filter_per_layer, layers_per_block=layers_per_block, pool_every=1, hidden_dims=hidden_dim, ycn=True)
# ========================
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.287, Accuracy 17.7): 100%|██████████████████████████████████| 850/850 [00:09<00:00, 91.47it/s]
# test_batch (Avg. Loss 2.269, Accuracy 23.2): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 105.58it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.247, Accuracy 23.5): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 83.58it/s]
# test_batch (Avg. Loss 2.218, Accuracy 24.3): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 100.61it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 2.182, Accuracy 25.0): 100%|██████████████████████████████████| 850/850 [00:09<00:00, 88.27it/s]
# test_batch (Avg. Loss 2.136, Accuracy 26.8): 100%|███████████████████████████████████| 625/625 [00:06<00:00, 99.84it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 2.096, Accuracy 27.9): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 58.63it/s]
# test_batch (Avg. Loss 2.048, Accuracy 28.2): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 101.40it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 2.024, Accuracy 29.7): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 108.18it/s]
# test_batch (Avg. Loss 1.988, Accuracy 29.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 149.20it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.976, Accuracy 31.0): 100%|█████████████████████████████████| 850/850 [00:07<00:00, 109.76it/s]
# test_batch (Avg. Loss 1.947, Accuracy 30.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 138.67it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.940, Accuracy 32.4): 100%|██████████████████████████████████| 850/850 [00:08<00:00, 95.08it/s]
# test_batch (Avg. Loss 1.917, Accuracy 32.8): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 152.11it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.910, Accuracy 33.7): 100%|█████████████████████████████████| 850/850 [00:07<00:00, 110.13it/s]
# test_batch (Avg. Loss 1.886, Accuracy 34.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.05it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.884, Accuracy 34.6): 100%|█████████████████████████████████| 850/850 [00:07<00:00, 113.44it/s]
# test_batch (Avg. Loss 1.863, Accuracy 34.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.15it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.862, Accuracy 35.5): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 104.06it/s]
# test_batch (Avg. Loss 1.842, Accuracy 36.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.56it/s]
# test_batch (Avg. Loss 1.846, Accuracy 36.0): 100%|██████████████████████████████████| 834/834 [00:07<00:00, 109.97it/s]
# ==================== Test Results ====================
# Test Accuracy: 35.98
# Test Accuracy: 1.846207135301128
# ======================================================
# *** Output file ./results\exp1_1_[32]_[100].json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.283, Accuracy 17.5): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 105.66it/s]
# test_batch (Avg. Loss 2.259, Accuracy 21.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 146.55it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.229, Accuracy 24.3): 100%|█████████████████████████████████| 850/850 [00:07<00:00, 106.65it/s]
# test_batch (Avg. Loss 2.190, Accuracy 25.6): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 130.45it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 2.149, Accuracy 27.3): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 101.13it/s]
# test_batch (Avg. Loss 2.099, Accuracy 27.6): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 159.15it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 2.066, Accuracy 28.8): 100%|█████████████████████████████████| 850/850 [00:07<00:00, 107.40it/s]
# test_batch (Avg. Loss 2.027, Accuracy 29.6): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 158.03it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 2.008, Accuracy 30.1): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 101.72it/s]
# test_batch (Avg. Loss 1.977, Accuracy 31.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.82it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.967, Accuracy 31.5): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 102.50it/s]
# test_batch (Avg. Loss 1.942, Accuracy 30.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 156.17it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.936, Accuracy 32.8): 100%|█████████████████████████████████| 850/850 [00:07<00:00, 106.64it/s]
# test_batch (Avg. Loss 1.914, Accuracy 32.6): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 147.34it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.909, Accuracy 33.6): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 104.17it/s]
# test_batch (Avg. Loss 1.887, Accuracy 33.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.40it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.885, Accuracy 34.6): 100%|█████████████████████████████████| 850/850 [00:07<00:00, 107.96it/s]
# test_batch (Avg. Loss 1.869, Accuracy 34.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 143.51it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.864, Accuracy 35.3): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 101.08it/s]
# test_batch (Avg. Loss 1.848, Accuracy 34.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.43it/s]
# test_batch (Avg. Loss 1.849, Accuracy 35.8): 100%|██████████████████████████████████| 834/834 [00:07<00:00, 111.07it/s]
# ==================== Test Results ====================
# Test Accuracy: 35.78
# Test Accuracy: 1.8490714549446563
# ======================================================
# *** Output file ./results\exp1_1_[32]_[150].json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=200, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=200, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.281, Accuracy 19.6): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 101.80it/s]
# test_batch (Avg. Loss 2.256, Accuracy 26.1): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 168.56it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.226, Accuracy 26.6): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 101.47it/s]
# test_batch (Avg. Loss 2.186, Accuracy 28.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 150.60it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 2.142, Accuracy 29.0): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 101.64it/s]
# test_batch (Avg. Loss 2.089, Accuracy 29.3): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 172.08it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 2.052, Accuracy 30.1): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 101.67it/s]
# test_batch (Avg. Loss 2.010, Accuracy 31.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 150.10it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.990, Accuracy 31.4): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 101.63it/s]
# test_batch (Avg. Loss 1.960, Accuracy 30.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 147.09it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.949, Accuracy 32.4): 100%|██████████████████████████████████| 850/850 [00:08<00:00, 98.45it/s]
# test_batch (Avg. Loss 1.925, Accuracy 32.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 147.30it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.917, Accuracy 33.4): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 101.34it/s]
# test_batch (Avg. Loss 1.896, Accuracy 33.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 150.46it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.891, Accuracy 34.4): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 101.74it/s]
# test_batch (Avg. Loss 1.874, Accuracy 34.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 147.89it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.867, Accuracy 35.2): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 102.25it/s]
# test_batch (Avg. Loss 1.849, Accuracy 34.6): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 124.80it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.846, Accuracy 36.2): 100%|█████████████████████████████████| 850/850 [00:08<00:00, 103.44it/s]
# test_batch (Avg. Loss 1.829, Accuracy 35.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 150.02it/s]
# test_batch (Avg. Loss 1.833, Accuracy 35.8): 100%|██████████████████████████████████| 834/834 [00:07<00:00, 106.51it/s]
# ==================== Test Results ====================
# Test Accuracy: 35.79
# Test Accuracy: 1.833466397200843
# ======================================================
# *** Output file ./results\exp1_1_[32]_[200].json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.263, Accuracy 16.9): 100%|██████████████████████████████████| 850/850 [00:11<00:00, 71.00it/s]
# test_batch (Avg. Loss 2.218, Accuracy 25.6): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 121.67it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.169, Accuracy 26.4): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 68.92it/s]
# test_batch (Avg. Loss 2.111, Accuracy 28.8): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 128.31it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 2.066, Accuracy 29.4): 100%|██████████████████████████████████| 850/850 [00:11<00:00, 71.07it/s]
# test_batch (Avg. Loss 2.015, Accuracy 30.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 131.55it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.987, Accuracy 31.6): 100%|██████████████████████████████████| 850/850 [00:11<00:00, 71.46it/s]
# test_batch (Avg. Loss 1.949, Accuracy 32.5): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 101.63it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.933, Accuracy 33.7): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 68.22it/s]
# test_batch (Avg. Loss 1.903, Accuracy 34.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 128.18it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.892, Accuracy 35.0): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 69.59it/s]
# test_batch (Avg. Loss 1.864, Accuracy 35.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 128.13it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.859, Accuracy 36.1): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 69.40it/s]
# test_batch (Avg. Loss 1.837, Accuracy 35.8): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 101.91it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.831, Accuracy 37.0): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 67.61it/s]
# test_batch (Avg. Loss 1.811, Accuracy 37.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 125.68it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.806, Accuracy 37.9): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 69.82it/s]
# test_batch (Avg. Loss 1.786, Accuracy 37.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 127.37it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.783, Accuracy 38.7): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 69.25it/s]
# test_batch (Avg. Loss 1.766, Accuracy 38.5): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 104.08it/s]
# test_batch (Avg. Loss 1.769, Accuracy 39.1): 100%|███████████████████████████████████| 834/834 [00:13<00:00, 63.23it/s]
# ==================== Test Results ====================
# Test Accuracy: 39.08
# Test Accuracy: 1.769452199947348
# ======================================================
# *** Output file ./results\exp1_1_[64]_[100].json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.257, Accuracy 21.4): 100%|██████████████████████████████████| 850/850 [00:11<00:00, 76.58it/s]
# test_batch (Avg. Loss 2.209, Accuracy 26.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 147.13it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.157, Accuracy 27.9): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 78.73it/s]
# test_batch (Avg. Loss 2.099, Accuracy 28.7): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 144.61it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 2.052, Accuracy 30.3): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 77.36it/s]
# test_batch (Avg. Loss 2.004, Accuracy 31.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 140.04it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.977, Accuracy 32.3): 100%|██████████████████████████████████| 850/850 [00:11<00:00, 76.77it/s]
# test_batch (Avg. Loss 1.942, Accuracy 32.7): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 147.37it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.926, Accuracy 33.7): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 77.87it/s]
# test_batch (Avg. Loss 1.900, Accuracy 33.6): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 147.20it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.889, Accuracy 35.0): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 77.65it/s]
# test_batch (Avg. Loss 1.866, Accuracy 34.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 133.26it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.859, Accuracy 36.1): 100%|██████████████████████████████████| 850/850 [00:11<00:00, 75.66it/s]
# test_batch (Avg. Loss 1.837, Accuracy 35.7): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 139.76it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.832, Accuracy 37.0): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 76.85it/s]
# test_batch (Avg. Loss 1.816, Accuracy 36.7): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 145.08it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.808, Accuracy 37.7): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 78.30it/s]
# test_batch (Avg. Loss 1.794, Accuracy 37.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 139.26it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.785, Accuracy 38.7): 100%|██████████████████████████████████| 850/850 [00:11<00:00, 76.78it/s]
# test_batch (Avg. Loss 1.767, Accuracy 37.8): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 144.51it/s]
# test_batch (Avg. Loss 1.768, Accuracy 38.9): 100%|██████████████████████████████████| 834/834 [00:08<00:00, 103.35it/s]
# ==================== Test Results ====================
# Test Accuracy: 38.87
# Test Accuracy: 1.7679014390321086
# ======================================================
# *** Output file ./results\exp1_1_[64]_[150].json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=200, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=200, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.258, Accuracy 20.6): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 70.27it/s]
# test_batch (Avg. Loss 2.209, Accuracy 24.5): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 106.75it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.157, Accuracy 28.7): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 80.59it/s]
# test_batch (Avg. Loss 2.097, Accuracy 29.8): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 160.79it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 2.051, Accuracy 30.9): 100%|██████████████████████████████████| 850/850 [00:11<00:00, 76.69it/s]
# test_batch (Avg. Loss 2.002, Accuracy 31.5): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 157.23it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.974, Accuracy 32.6): 100%|██████████████████████████████████| 850/850 [00:11<00:00, 71.53it/s]
# test_batch (Avg. Loss 1.938, Accuracy 33.3): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 103.94it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.923, Accuracy 34.0): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 69.69it/s]
# test_batch (Avg. Loss 1.898, Accuracy 34.5): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 159.28it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.885, Accuracy 35.1): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 79.94it/s]
# test_batch (Avg. Loss 1.862, Accuracy 35.3): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 168.78it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.854, Accuracy 36.2): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 82.44it/s]
# test_batch (Avg. Loss 1.833, Accuracy 36.3): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 167.97it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.827, Accuracy 37.1): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 82.72it/s]
# test_batch (Avg. Loss 1.809, Accuracy 37.0): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 167.00it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.803, Accuracy 38.0): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 82.74it/s]
# test_batch (Avg. Loss 1.785, Accuracy 37.8): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 169.24it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.780, Accuracy 38.8): 100%|██████████████████████████████████| 850/850 [00:10<00:00, 83.20it/s]
# test_batch (Avg. Loss 1.764, Accuracy 38.4): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 170.53it/s]
# test_batch (Avg. Loss 1.765, Accuracy 39.0): 100%|██████████████████████████████████| 834/834 [00:07<00:00, 110.42it/s]
# ==================== Test Results ====================
# Test Accuracy: 38.99
# Test Accuracy: 1.7651128914716432
# ======================================================
# *** Output file ./results\exp1_1_[64]_[200].json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=32768, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.212, Accuracy 23.6): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 65.43it/s]
# test_batch (Avg. Loss 2.123, Accuracy 28.8): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 150.02it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.058, Accuracy 30.4): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 66.33it/s]
# test_batch (Avg. Loss 1.997, Accuracy 29.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 149.67it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.962, Accuracy 32.4): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 66.65it/s]
# test_batch (Avg. Loss 1.924, Accuracy 32.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 105.55it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.906, Accuracy 34.2): 100%|██████████████████████████████████| 850/850 [00:13<00:00, 69.25it/s]
# test_batch (Avg. Loss 1.877, Accuracy 33.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 149.31it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.866, Accuracy 35.3): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 65.13it/s]
# test_batch (Avg. Loss 1.842, Accuracy 35.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 150.13it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.834, Accuracy 36.7): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 66.49it/s]
# test_batch (Avg. Loss 1.818, Accuracy 35.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 141.44it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.806, Accuracy 37.5): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 66.81it/s]
# test_batch (Avg. Loss 1.786, Accuracy 37.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 150.24it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.779, Accuracy 38.5): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 66.45it/s]
# test_batch (Avg. Loss 1.761, Accuracy 38.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 137.91it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.754, Accuracy 39.3): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 66.59it/s]
# test_batch (Avg. Loss 1.737, Accuracy 39.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 143.38it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.730, Accuracy 40.1): 100%|██████████████████████████████████| 850/850 [00:12<00:00, 66.49it/s]
# test_batch (Avg. Loss 1.712, Accuracy 40.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 149.77it/s]
# test_batch (Avg. Loss 1.713, Accuracy 40.6): 100%|███████████████████████████████████| 834/834 [00:08<00:00, 98.98it/s]
# ==================== Test Results ====================
# Test Accuracy: 40.59
# Test Accuracy: 1.7128424342873572
# ======================================================
# *** Output file ./results\exp1_1_[128]_[100].json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=32768, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.204, Accuracy 23.5): 100%|██████████████████████████████████| 850/850 [00:15<00:00, 53.31it/s]
# test_batch (Avg. Loss 2.108, Accuracy 27.7): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 106.26it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.046, Accuracy 30.3): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 58.09it/s]
# test_batch (Avg. Loss 1.983, Accuracy 32.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 126.70it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.953, Accuracy 32.8): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 60.05it/s]
# test_batch (Avg. Loss 1.917, Accuracy 33.5): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 123.81it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.901, Accuracy 34.5): 100%|██████████████████████████████████| 850/850 [00:15<00:00, 55.95it/s]
# test_batch (Avg. Loss 1.872, Accuracy 34.5): 100%|███████████████████████████████████| 625/625 [00:09<00:00, 63.02it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.863, Accuracy 35.8): 100%|██████████████████████████████████| 850/850 [00:17<00:00, 48.23it/s]
# test_batch (Avg. Loss 1.841, Accuracy 35.7): 100%|███████████████████████████████████| 625/625 [00:06<00:00, 97.87it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.833, Accuracy 36.8): 100%|██████████████████████████████████| 850/850 [00:16<00:00, 52.02it/s]
# test_batch (Avg. Loss 1.811, Accuracy 36.3): 100%|███████████████████████████████████| 625/625 [00:07<00:00, 79.55it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.805, Accuracy 37.8): 100%|██████████████████████████████████| 850/850 [00:16<00:00, 49.45it/s]
# test_batch (Avg. Loss 1.787, Accuracy 37.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 126.88it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.778, Accuracy 38.7): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 59.29it/s]
# test_batch (Avg. Loss 1.763, Accuracy 38.2): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 124.18it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.754, Accuracy 39.6): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 59.25it/s]
# test_batch (Avg. Loss 1.735, Accuracy 39.4): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 105.97it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.729, Accuracy 40.2): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 58.58it/s]
# test_batch (Avg. Loss 1.716, Accuracy 40.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 129.86it/s]
# test_batch (Avg. Loss 1.715, Accuracy 40.8): 100%|███████████████████████████████████| 834/834 [00:08<00:00, 94.99it/s]
# ==================== Test Results ====================
# Test Accuracy: 40.78
# Test Accuracy: 1.7150330983763404
# ======================================================
# *** Output file ./results\exp1_1_[128]_[150].json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=32768, out_features=200, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=200, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.210, Accuracy 22.3): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 58.96it/s]
# test_batch (Avg. Loss 2.124, Accuracy 28.2): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 107.30it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.062, Accuracy 29.5): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 58.09it/s]
# test_batch (Avg. Loss 2.003, Accuracy 30.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 129.78it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.971, Accuracy 32.0): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 59.34it/s]
# test_batch (Avg. Loss 1.935, Accuracy 31.7): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 126.03it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.916, Accuracy 34.0): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 58.87it/s]
# test_batch (Avg. Loss 1.887, Accuracy 33.7): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 141.82it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.877, Accuracy 35.1): 100%|██████████████████████████████████| 850/850 [00:13<00:00, 63.47it/s]
# test_batch (Avg. Loss 1.855, Accuracy 34.7): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 150.02it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.846, Accuracy 36.3): 100%|██████████████████████████████████| 850/850 [00:13<00:00, 58.74it/s]
# test_batch (Avg. Loss 1.826, Accuracy 36.4): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 116.71it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.818, Accuracy 37.6): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 59.27it/s]
# test_batch (Avg. Loss 1.799, Accuracy 36.8): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 128.50it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.792, Accuracy 38.4): 100%|██████████████████████████████████| 850/850 [00:15<00:00, 53.66it/s]
# test_batch (Avg. Loss 1.774, Accuracy 37.4): 100%|███████████████████████████████████| 625/625 [00:06<00:00, 91.60it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.767, Accuracy 39.1): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 58.97it/s]
# test_batch (Avg. Loss 1.747, Accuracy 39.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 126.42it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.743, Accuracy 40.0): 100%|██████████████████████████████████| 850/850 [00:14<00:00, 58.93it/s]
# test_batch (Avg. Loss 1.725, Accuracy 39.5): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 106.95it/s]
# test_batch (Avg. Loss 1.727, Accuracy 40.2): 100%|███████████████████████████████████| 834/834 [00:11<00:00, 70.10it/s]
# ==================== Test Results ====================
# Test Accuracy: 40.24
# Test Accuracy: 1.7271416162272437
# ======================================================
# *** Output file ./results\exp1_1_[128]_[200].json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=65536, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.165, Accuracy 25.5): 100%|██████████████████████████████████| 850/850 [00:23<00:00, 36.63it/s]
# test_batch (Avg. Loss 2.047, Accuracy 30.4): 100%|███████████████████████████████████| 625/625 [00:06<00:00, 98.09it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.987, Accuracy 32.4): 100%|██████████████████████████████████| 850/850 [00:21<00:00, 39.76it/s]
# test_batch (Avg. Loss 1.928, Accuracy 33.4): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 102.26it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.905, Accuracy 34.4): 100%|██████████████████████████████████| 850/850 [00:22<00:00, 37.58it/s]
# test_batch (Avg. Loss 1.870, Accuracy 35.1): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 113.66it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.854, Accuracy 36.1): 100%|██████████████████████████████████| 850/850 [00:21<00:00, 38.26it/s]
# test_batch (Avg. Loss 1.836, Accuracy 35.3): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 101.48it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.814, Accuracy 37.4): 100%|██████████████████████████████████| 850/850 [00:20<00:00, 40.67it/s]
# test_batch (Avg. Loss 1.794, Accuracy 37.5): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 114.11it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.779, Accuracy 38.7): 100%|██████████████████████████████████| 850/850 [00:20<00:00, 40.78it/s]
# test_batch (Avg. Loss 1.760, Accuracy 38.6): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 107.41it/s]
# --- EPOCH 7/10 ---
# train_batch (1.749):  63%|█████████████████████████████████████▍                     | 539/850 [00:13<00:07, 41.03it/s]
# KeyboardInterrupt

# %%
plot_exp_results('exp1_*.json')

# after observing the graphs, we can see that the best results are with 3 layers per block, 128 filters per layer and 100 hidden dims

# best graph seems to be:
# layers_per_block = 3, filters_per_layer = [256], hidden_dims = [150]
# Out:
# common config:  {'run_name': 'Texp1_3_[64]_[200]_dropout0.2', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'pool_every': 1, 'hidden_dims': [200], 'ycn': True, 'kw': {}}

# %% [markdown]
# ### 2. Learning rate and optimization method
# Tune the optimization algorithm (try SGD with momentum and Adam) and the learning rate (try values between 0.0005-1, try no more than five values).

# %%
# set ycn=True when you call experiments.run_experiment(...).
# Use meaningful names!
# ====== YOUR CODE: ======
experiment_num = 2

# when run with Adam:
learning_rates_list = [0.0005, 0.00052, 0.00056, 0.00058, 0.00065]
for lr in learning_rates_list:
    experiments.run_experiment("exp" + f"{experiment_num}" + "_adam_lr" + f"{lr}", seed=seed, bs_train=50, batches=10, epochs=10, early_stopping=5,
                           filters_per_layer=[256], layers_per_block=3, pool_every=1, hidden_dims=[150], lr=lr,ycn=True)
# ========================
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Dropout2d(p=0.2, inplace=False)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Dropout2d(p=0.2, inplace=False)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): Dropout2d(p=0.2, inplace=False)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.638, Accuracy 40.2): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.77it/s]
# test_batch (Avg. Loss 1.319, Accuracy 52.4): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 156.76it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.294, Accuracy 53.5): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.95it/s]
# test_batch (Avg. Loss 1.133, Accuracy 60.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.89it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.144, Accuracy 59.4): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.85it/s]
# test_batch (Avg. Loss 1.035, Accuracy 63.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.47it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.044, Accuracy 63.3): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.74it/s]
# test_batch (Avg. Loss 0.930, Accuracy 68.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.28it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.965, Accuracy 66.5): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.82it/s]
# test_batch (Avg. Loss 0.892, Accuracy 68.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.63it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.909, Accuracy 68.2): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.83it/s]
# test_batch (Avg. Loss 0.844, Accuracy 70.1): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 156.84it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.868, Accuracy 70.1): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.83it/s]
# test_batch (Avg. Loss 0.810, Accuracy 71.6): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.63it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.829, Accuracy 71.3): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.82it/s]
# test_batch (Avg. Loss 0.776, Accuracy 72.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.51it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.799, Accuracy 72.2): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.80it/s]
# test_batch (Avg. Loss 0.760, Accuracy 73.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.71it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.771, Accuracy 73.0): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.80it/s]
# test_batch (Avg. Loss 0.752, Accuracy 73.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 156.13it/s]
# test_batch (Avg. Loss 0.767, Accuracy 73.6): 100%|██████████████████████████████████| 834/834 [00:07<00:00, 112.25it/s]
# ==================== Test Results ====================
# Test Accuracy: 73.56
# Test Accuracy: 0.7674435661386528
# ======================================================
# *** Output file ./results\exp2_adam_lr0.0007.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Dropout2d(p=0.2, inplace=False)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Dropout2d(p=0.2, inplace=False)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): Dropout2d(p=0.2, inplace=False)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.632, Accuracy 40.5): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.82it/s]
# test_batch (Avg. Loss 1.313, Accuracy 52.9): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 156.45it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.280, Accuracy 54.2): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.88it/s]
# test_batch (Avg. Loss 1.126, Accuracy 60.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.44it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.130, Accuracy 60.1): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.75it/s]
# test_batch (Avg. Loss 1.048, Accuracy 62.6): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 157.45it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.035, Accuracy 63.5): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.80it/s]
# test_batch (Avg. Loss 0.919, Accuracy 68.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 156.13it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.959, Accuracy 66.6): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.81it/s]
# test_batch (Avg. Loss 0.918, Accuracy 67.8): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 156.37it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.908, Accuracy 68.1): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.79it/s]
# test_batch (Avg. Loss 0.849, Accuracy 70.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.66it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.858, Accuracy 70.2): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.85it/s]
# test_batch (Avg. Loss 0.821, Accuracy 71.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.66it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.828, Accuracy 71.4): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.84it/s]
# test_batch (Avg. Loss 0.806, Accuracy 71.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.28it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.788, Accuracy 72.5): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.81it/s]
# test_batch (Avg. Loss 0.762, Accuracy 73.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 156.17it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.769, Accuracy 73.2): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 30.82it/s]
# test_batch (Avg. Loss 0.767, Accuracy 73.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.16it/s]
# test_batch (Avg. Loss 0.771, Accuracy 73.2): 100%|██████████████████████████████████| 834/834 [00:07<00:00, 109.73it/s]
# ==================== Test Results ====================
# Test Accuracy: 73.21
# Test Accuracy: 0.771474976369517
# ======================================================
# *** Output file ./results\exp2_adam_lr0.00065.json written

# %%
#when run with SGD with momentum 0.9:
learning_rates_list = [0.0027, 0.0023, 0.0015, 0.05, 0.003]
for lr in learning_rates_list:
    experiments.run_experiment("exp" + f"{experiment_num}" + "_sgd0.9_lr" + f"{lr}", seed=seed, bs_train=50, batches=10, epochs=10, early_stopping=5,
                           filters_per_layer=[256], layers_per_block=3, pool_every=1, hidden_dims=[150], lr=lr,ycn=True)
# ========================
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Dropout2d(p=0.2, inplace=False)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Dropout2d(p=0.2, inplace=False)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): Dropout2d(p=0.2, inplace=False)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.105, Accuracy 22.6): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.89it/s]
# test_batch (Avg. Loss 1.792, Accuracy 35.3): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 158.08it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.685, Accuracy 39.4): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 32.01it/s]
# test_batch (Avg. Loss 1.564, Accuracy 43.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 147.34it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.512, Accuracy 45.2): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.82it/s]
# test_batch (Avg. Loss 1.411, Accuracy 48.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 143.32it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.388, Accuracy 50.1): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.45it/s]
# test_batch (Avg. Loss 1.307, Accuracy 52.7): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 143.68it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.283, Accuracy 54.1): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.56it/s]
# test_batch (Avg. Loss 1.182, Accuracy 57.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 143.02it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.186, Accuracy 57.9): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.12it/s]
# test_batch (Avg. Loss 1.104, Accuracy 60.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 143.91it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.106, Accuracy 60.9): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.29it/s]
# test_batch (Avg. Loss 1.038, Accuracy 63.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 141.76it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.030, Accuracy 63.9): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 32.04it/s]
# test_batch (Avg. Loss 0.968, Accuracy 65.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 146.23it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.963, Accuracy 66.3): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.84it/s]
# test_batch (Avg. Loss 0.907, Accuracy 68.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.04it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.910, Accuracy 68.3): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.95it/s]
# test_batch (Avg. Loss 0.894, Accuracy 69.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 151.66it/s]
# test_batch (Avg. Loss 0.907, Accuracy 68.9): 100%|██████████████████████████████████| 834/834 [00:07<00:00, 106.21it/s]
# ==================== Test Results ====================
# Test Accuracy: 68.89
# Test Accuracy: 0.9065018138117927
# ======================================================
# *** Output file ./results\exp2_lr0.0027_sgd0.9.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Dropout2d(p=0.2, inplace=False)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Dropout2d(p=0.2, inplace=False)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): Dropout2d(p=0.2, inplace=False)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.135, Accuracy 21.1): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 32.25it/s]
# test_batch (Avg. Loss 1.860, Accuracy 32.9): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 162.63it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.735, Accuracy 37.7): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 32.17it/s]
# test_batch (Avg. Loss 1.616, Accuracy 41.3): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 164.73it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.550, Accuracy 44.1): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.78it/s]
# test_batch (Avg. Loss 1.461, Accuracy 46.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.09it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.434, Accuracy 48.4): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.66it/s]
# test_batch (Avg. Loss 1.350, Accuracy 51.3): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 161.71it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.336, Accuracy 52.1): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.59it/s]
# test_batch (Avg. Loss 1.247, Accuracy 55.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.37it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.245, Accuracy 55.8): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.63it/s]
# test_batch (Avg. Loss 1.158, Accuracy 58.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.63it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.166, Accuracy 58.9): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.44it/s]
# test_batch (Avg. Loss 1.089, Accuracy 61.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.97it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.091, Accuracy 61.6): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.45it/s]
# test_batch (Avg. Loss 1.023, Accuracy 63.6): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 162.13it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.022, Accuracy 64.1): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 32.24it/s]
# test_batch (Avg. Loss 0.958, Accuracy 66.3): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 162.93it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.969, Accuracy 66.1): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.86it/s]
# test_batch (Avg. Loss 0.931, Accuracy 67.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.13it/s]
# test_batch (Avg. Loss 0.940, Accuracy 67.4): 100%|██████████████████████████████████| 834/834 [00:07<00:00, 109.36it/s]
# ==================== Test Results ====================
# Test Accuracy: 67.42
# Test Accuracy: 0.9404791277661312
# ======================================================
# *** Output file ./results\exp2_lr0.0023_sgd0.9.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Dropout2d(p=0.2, inplace=False)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Dropout2d(p=0.2, inplace=False)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): Dropout2d(p=0.2, inplace=False)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.207, Accuracy 17.5): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.37it/s]
# test_batch (Avg. Loss 1.985, Accuracy 27.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.37it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.895, Accuracy 32.0): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.43it/s]
# test_batch (Avg. Loss 1.775, Accuracy 35.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 152.11it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.661, Accuracy 40.3): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.19it/s]
# test_batch (Avg. Loss 1.581, Accuracy 41.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.78it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.548, Accuracy 44.0): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.33it/s]
# test_batch (Avg. Loss 1.459, Accuracy 47.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.15it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.467, Accuracy 47.1): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.44it/s]
# test_batch (Avg. Loss 1.389, Accuracy 49.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.28it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.393, Accuracy 49.7): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.40it/s]
# test_batch (Avg. Loss 1.311, Accuracy 52.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 152.48it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.328, Accuracy 52.5): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.32it/s]
# test_batch (Avg. Loss 1.250, Accuracy 55.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.53it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.264, Accuracy 55.1): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.32it/s]
# test_batch (Avg. Loss 1.186, Accuracy 57.7): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.49it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.199, Accuracy 57.6): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.34it/s]
# test_batch (Avg. Loss 1.121, Accuracy 60.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.09it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.145, Accuracy 59.6): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.42it/s]
# test_batch (Avg. Loss 1.085, Accuracy 61.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 152.70it/s]
# test_batch (Avg. Loss 1.088, Accuracy 61.7): 100%|██████████████████████████████████| 834/834 [00:07<00:00, 108.30it/s]
# ==================== Test Results ====================
# Test Accuracy: 61.71
# Test Accuracy: 1.087582346596878
# ======================================================
# *** Output file ./results\exp2_lr0.0015_sgd0.9.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Dropout2d(p=0.2, inplace=False)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Dropout2d(p=0.2, inplace=False)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): Dropout2d(p=0.2, inplace=False)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.858, Accuracy 31.2): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.50it/s]
# test_batch (Avg. Loss 1.643, Accuracy 38.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.36it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.571, Accuracy 43.7): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.61it/s]
# test_batch (Avg. Loss 1.368, Accuracy 51.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.49it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.462, Accuracy 47.8): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.52it/s]
# test_batch (Avg. Loss 1.297, Accuracy 52.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 155.51it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.392, Accuracy 50.7): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.57it/s]
# test_batch (Avg. Loss 1.272, Accuracy 54.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 156.00it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.325, Accuracy 53.1): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.55it/s]
# test_batch (Avg. Loss 1.225, Accuracy 56.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.82it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.318, Accuracy 53.4): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.58it/s]
# test_batch (Avg. Loss 1.365, Accuracy 51.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.19it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.283, Accuracy 55.1): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.54it/s]
# test_batch (Avg. Loss 1.187, Accuracy 58.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.28it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.270, Accuracy 55.7): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.56it/s]
# test_batch (Avg. Loss 1.126, Accuracy 59.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.15it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.236, Accuracy 56.9): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.65it/s]
# test_batch (Avg. Loss 1.094, Accuracy 61.5): 100%|██████████████████████████████████| 625/625 [00:03<00:00, 164.26it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.227, Accuracy 57.2): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.81it/s]
# test_batch (Avg. Loss 1.119, Accuracy 60.6): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.41it/s]
# test_batch (Avg. Loss 1.109, Accuracy 61.2): 100%|██████████████████████████████████| 834/834 [00:07<00:00, 109.24it/s]
# ==================== Test Results ====================
# Test Accuracy: 61.17
# Test Accuracy: 1.1093564225400951
# ======================================================
# *** Output file ./results\exp2_lr0.05_sgd0.9.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Dropout2d(p=0.2, inplace=False)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Dropout2d(p=0.2, inplace=False)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): Dropout2d(p=0.2, inplace=False)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.081, Accuracy 23.4): 100%|██████████████████████████████████| 850/850 [00:26<00:00, 31.48it/s]
# test_batch (Avg. Loss 1.751, Accuracy 36.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 154.86it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.654, Accuracy 40.1): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.40it/s]
# test_batch (Avg. Loss 1.537, Accuracy 44.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 151.04it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.484, Accuracy 46.2): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.34it/s]
# test_batch (Avg. Loss 1.397, Accuracy 48.7): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 151.66it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.355, Accuracy 51.4): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.39it/s]
# test_batch (Avg. Loss 1.282, Accuracy 53.8): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 152.59it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.246, Accuracy 55.6): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.35it/s]
# test_batch (Avg. Loss 1.142, Accuracy 59.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 152.77it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.147, Accuracy 59.3): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.40it/s]
# test_batch (Avg. Loss 1.059, Accuracy 61.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 152.40it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.064, Accuracy 62.6): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.38it/s]
# test_batch (Avg. Loss 1.004, Accuracy 64.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 152.63it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.990, Accuracy 65.5): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.36it/s]
# test_batch (Avg. Loss 0.942, Accuracy 66.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 151.59it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.923, Accuracy 67.8): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.31it/s]
# test_batch (Avg. Loss 0.884, Accuracy 68.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 153.37it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.872, Accuracy 69.6): 100%|██████████████████████████████████| 850/850 [00:27<00:00, 31.39it/s]
# test_batch (Avg. Loss 0.869, Accuracy 69.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 151.44it/s]
# test_batch (Avg. Loss 0.882, Accuracy 69.4): 100%|██████████████████████████████████| 834/834 [00:07<00:00, 106.28it/s]
# ==================== Test Results ====================
# Test Accuracy: 69.44
# Test Accuracy: 0.8818087431488277
# ======================================================
# *** Output file ./results\exp2_lr0.003_sgd0.9.json written

# %%
plot_exp_results('exp2_adam*.json') # plot all results adam
plot_exp_results('exp2_sgd0.9*.json') # plot all results sgd with momentum 0.9
# Out:
# common config:  {'run_name': 'exp2_adam_lr0.00065', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.00065, 'reg': 0.001, 'pool_every': 1, 'hidden_dims': [150], 'ycn': True, 'kw': {}}
# common config:  {'run_name': 'exp2_lr0.05_sgd0.9', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.05, 'reg': 0.001, 'pool_every': 1, 'hidden_dims': [150], 'ycn': True, 'kw': {}}

# %% [markdown]
# **Answer in your Report:** Why should we add the momentum to SGD? What is the main two improvments adam has comparing to the simple SGD? What was the best optimization algorithm and best learning rate you've found?
#
# Summarize this section results in your report.
#
# **Note** - you will need to change the optimization used in experiments.run_experiment(...).

# %% [markdown]
# ### 3. Add Batch Normalization
# Add batch normalization to your network. You may want to read this blog before:
# https://www.baeldung.com/cs/batch-normalization-cnn

# %%
# set ycn=True when you call experiments.run_experiment(...)
# Use meaningful names!
# ====== YOUR CODE: ======
experiment_num = 3

# added batch normalization to the model
learning_rates_list = [0.00058, 0.0006, 0.00055, 0.0007, 0.0005]
for lr in learning_rates_list:
    experiments.run_experiment("exp" + f"{experiment_num}" + "_with_batchnorm_lr" + f"{lr}", seed=seed, bs_train=50, batches=10, epochs=10, early_stopping=5,
                               filters_per_layer=[256], layers_per_block=3, pool_every=1, hidden_dims=[150], lr=lr,ycn=True)
# ========================
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.097, Accuracy 60.6): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.64it/s]
# test_batch (Avg. Loss 0.848, Accuracy 69.6): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 102.16it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 0.685, Accuracy 76.0): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 29.01it/s]
# test_batch (Avg. Loss 0.792, Accuracy 72.8): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 119.18it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 0.480, Accuracy 83.2): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.76it/s]
# test_batch (Avg. Loss 0.727, Accuracy 76.0): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 101.33it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 0.316, Accuracy 89.0): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.13it/s]
# test_batch (Avg. Loss 0.707, Accuracy 77.4): 100%|███████████████████████████████████| 625/625 [00:06<00:00, 95.36it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.200, Accuracy 93.0): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.38it/s]
# test_batch (Avg. Loss 0.761, Accuracy 78.0): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 116.58it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.128, Accuracy 95.5): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.48it/s]
# test_batch (Avg. Loss 0.885, Accuracy 78.1): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 119.78it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.103, Accuracy 96.4): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.55it/s]
# test_batch (Avg. Loss 0.907, Accuracy 77.5): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 111.05it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.085, Accuracy 97.1): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.19it/s]
# test_batch (Avg. Loss 1.058, Accuracy 76.5): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 117.33it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.081, Accuracy 97.2): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.50it/s]
# test_batch (Avg. Loss 1.123, Accuracy 76.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 117.95it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.074, Accuracy 97.4): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.46it/s]
# test_batch (Avg. Loss 1.029, Accuracy 78.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 119.34it/s]
# test_batch (Avg. Loss 1.074, Accuracy 78.4): 100%|███████████████████████████████████| 834/834 [00:10<00:00, 79.53it/s]
# ==================== Test Results ====================
# Test Accuracy: 78.43
# Test Accuracy: 1.0737740267452012
# ======================================================
# *** Output file ./results\exp3_with_batchnorm_lr0.00058.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.103, Accuracy 60.8): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 28.70it/s]
# test_batch (Avg. Loss 0.827, Accuracy 71.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 135.37it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 0.686, Accuracy 75.9): 100%|██████████████████████████████████| 850/850 [00:29<00:00, 28.88it/s]
# test_batch (Avg. Loss 0.714, Accuracy 75.5): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 104.76it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 0.487, Accuracy 83.0): 100%|██████████████████████████████████| 850/850 [00:29<00:00, 28.88it/s]
# test_batch (Avg. Loss 0.941, Accuracy 72.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 136.70it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 0.324, Accuracy 88.7): 100%|██████████████████████████████████| 850/850 [00:29<00:00, 28.88it/s]
# test_batch (Avg. Loss 0.696, Accuracy 78.1): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 103.87it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.200, Accuracy 93.0): 100%|██████████████████████████████████| 850/850 [00:29<00:00, 28.86it/s]
# test_batch (Avg. Loss 0.721, Accuracy 78.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 136.67it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.129, Accuracy 95.6): 100%|██████████████████████████████████| 850/850 [00:29<00:00, 28.93it/s]
# test_batch (Avg. Loss 0.996, Accuracy 75.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 133.52it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.103, Accuracy 96.4): 100%|██████████████████████████████████| 850/850 [00:29<00:00, 28.81it/s]
# test_batch (Avg. Loss 0.966, Accuracy 77.8): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 136.61it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.089, Accuracy 96.9): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.07it/s]
# test_batch (Avg. Loss 1.009, Accuracy 77.6): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 118.13it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.074, Accuracy 97.4): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.30it/s]
# test_batch (Avg. Loss 1.051, Accuracy 78.0): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 100.24it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.069, Accuracy 97.7): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 26.58it/s]
# test_batch (Avg. Loss 1.263, Accuracy 76.8): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 117.90it/s]
# Early stopping after 9 epochs
# test_batch (Avg. Loss 1.261, Accuracy 76.7): 100%|███████████████████████████████████| 834/834 [00:13<00:00, 63.07it/s]
# ==================== Test Results ====================
# Test Accuracy: 76.65
# Test Accuracy: 1.2613909311986353
# ======================================================
# *** Output file ./results\exp3_with_batchnorm_lr0.0006.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.096, Accuracy 60.6): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.92it/s]
# test_batch (Avg. Loss 0.826, Accuracy 71.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 118.73it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 0.683, Accuracy 76.2): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.33it/s]
# test_batch (Avg. Loss 0.687, Accuracy 75.4): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 119.22it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 0.483, Accuracy 83.2): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.32it/s]
# test_batch (Avg. Loss 0.800, Accuracy 73.7): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 117.55it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 0.319, Accuracy 88.8): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.01it/s]
# test_batch (Avg. Loss 0.705, Accuracy 77.9): 100%|███████████████████████████████████| 625/625 [00:08<00:00, 72.52it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.195, Accuracy 93.2): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 26.79it/s]
# test_batch (Avg. Loss 0.709, Accuracy 79.6): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 112.63it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.122, Accuracy 95.8): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.06it/s]
# test_batch (Avg. Loss 0.834, Accuracy 78.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 112.35it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.093, Accuracy 96.8): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.09it/s]
# test_batch (Avg. Loss 1.062, Accuracy 75.4): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 117.15it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.090, Accuracy 96.8): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.10it/s]
# test_batch (Avg. Loss 1.046, Accuracy 77.7): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 122.21it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.077, Accuracy 97.3): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.16it/s]
# test_batch (Avg. Loss 1.009, Accuracy 78.5): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 115.29it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.065, Accuracy 97.8): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.16it/s]
# test_batch (Avg. Loss 1.108, Accuracy 77.9): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 115.33it/s]
# Early stopping after 9 epochs
# test_batch (Avg. Loss 1.122, Accuracy 77.9): 100%|███████████████████████████████████| 834/834 [00:13<00:00, 62.16it/s]
# ==================== Test Results ====================
# Test Accuracy: 77.88
# Test Accuracy: 1.1220027311651382
# ======================================================
# *** Output file ./results\exp3_with_batchnorm_lr0.00055.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.110, Accuracy 60.6): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.89it/s]
# test_batch (Avg. Loss 0.841, Accuracy 70.2): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 115.91it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 0.695, Accuracy 75.7): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.31it/s]
# test_batch (Avg. Loss 0.751, Accuracy 73.8): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 117.30it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 0.496, Accuracy 82.6): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.45it/s]
# test_batch (Avg. Loss 0.703, Accuracy 76.6): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 120.01it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 0.344, Accuracy 87.8): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.20it/s]
# test_batch (Avg. Loss 0.745, Accuracy 76.8): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 114.45it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.217, Accuracy 92.6): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 26.18it/s]
# test_batch (Avg. Loss 0.860, Accuracy 74.9): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 106.65it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.148, Accuracy 94.9): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.23it/s]
# test_batch (Avg. Loss 0.884, Accuracy 76.8): 100%|███████████████████████████████████| 625/625 [00:08<00:00, 77.41it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.112, Accuracy 96.2): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.36it/s]
# test_batch (Avg. Loss 0.960, Accuracy 77.5): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 120.87it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.094, Accuracy 96.7): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.36it/s]
# test_batch (Avg. Loss 1.037, Accuracy 77.5): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 111.71it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.088, Accuracy 97.0): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 27.17it/s]
# test_batch (Avg. Loss 1.182, Accuracy 76.8): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 110.97it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.078, Accuracy 97.4): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 28.20it/s]
# test_batch (Avg. Loss 1.156, Accuracy 77.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 123.98it/s]
# test_batch (Avg. Loss 1.137, Accuracy 77.2): 100%|███████████████████████████████████| 834/834 [00:12<00:00, 61.14it/s]
# ==================== Test Results ====================
# Test Accuracy: 77.19
# Test Accuracy: 1.1371243549742551
# ======================================================
# *** Output file ./results\exp3_with_batchnorm_lr0.0007.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.099, Accuracy 60.7): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 28.32it/s]
# test_batch (Avg. Loss 0.856, Accuracy 69.6): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 120.66it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 0.675, Accuracy 76.4): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.98it/s]
# test_batch (Avg. Loss 0.689, Accuracy 75.4): 100%|███████████████████████████████████| 625/625 [00:06<00:00, 95.16it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 0.474, Accuracy 83.3): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.98it/s]
# test_batch (Avg. Loss 0.724, Accuracy 75.8): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 126.57it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 0.304, Accuracy 89.3): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.85it/s]
# test_batch (Avg. Loss 0.670, Accuracy 78.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 126.47it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.181, Accuracy 93.8): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.99it/s]
# test_batch (Avg. Loss 0.855, Accuracy 75.8): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 128.60it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.122, Accuracy 95.8): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.88it/s]
# test_batch (Avg. Loss 0.798, Accuracy 78.7): 100%|███████████████████████████████████| 625/625 [00:07<00:00, 83.83it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.090, Accuracy 96.9): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 28.09it/s]
# test_batch (Avg. Loss 0.891, Accuracy 79.0): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 122.43it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.082, Accuracy 97.1): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.97it/s]
# test_batch (Avg. Loss 0.889, Accuracy 78.5): 100%|███████████████████████████████████| 625/625 [00:06<00:00, 89.32it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.070, Accuracy 97.5): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.82it/s]
# test_batch (Avg. Loss 0.982, Accuracy 77.9): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 126.03it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.061, Accuracy 97.9): 100%|██████████████████████████████████| 850/850 [00:30<00:00, 27.94it/s]
# test_batch (Avg. Loss 1.097, Accuracy 77.0): 100%|███████████████████████████████████| 625/625 [00:06<00:00, 96.02it/s]
# test_batch (Avg. Loss 1.171, Accuracy 76.5): 100%|███████████████████████████████████| 834/834 [00:14<00:00, 55.79it/s]
# ==================== Test Results ====================
# Test Accuracy: 76.53
# Test Accuracy: 1.1706569841466505
# ======================================================
# *** Output file ./results\exp3_with_batchnorm_lr0.0005.json written

# %%
plot_exp_results('exp3_*.json') # plot your experiments results
# Out:
# common config:  {'run_name': 'exp3_with_batchnorm_lr0.0007', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.0007, 'reg': 0.001, 'pool_every': 1, 'hidden_dims': [150], 'ycn': True, 'kw': {}}

# %% [markdown]
# **Answer in your Report:** What is the purpose of batch normalization (why do we use it)?
# Did the Batch normalization improve the network preformance?
# Summeraize this section results in your report.

# %% [markdown]
# ### 4. Regularization
# Try to add regularization to your optimization. In particular add L2 regularization (read about weight_decay in adam) and dropout layer to your network (try them separately).

# %%
# set ycn=True when you call experiments.run_experiment(...)
# Use meaningful names!
# ====== YOUR CODE: ======
experiment_num = 4

# added L2 to the model in the optimizer Adam, without dropout
learning_rates_list = [0.00058, 0.0006, 0.00055, 0.0007, 0.0005]
for lr in learning_rates_list:
    experiments.run_experiment("exp" + f"{experiment_num}" + "_withL2_no_dropout_lr" + f"{lr}", seed=seed, bs_train=50, batches=10, epochs=10, early_stopping=5,
                               filters_per_layer=[256], layers_per_block=3, pool_every=1, hidden_dims=[150], lr=lr,ycn=True)

# %%
# added dropout to the model, without L2
experiment_num = 4
for lr in learning_rates_list:
    experiments.run_experiment("exp" + f"{experiment_num}" + "_noL2_with_dropout_lr" + f"{lr}", seed=seed, bs_train=50, batches=10, epochs=10, early_stopping=5,
                               filters_per_layer=[256], layers_per_block=3, pool_every=1, hidden_dims=[150], lr=lr,ycn=True)
# ========================
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Dropout2d(p=0.2, inplace=False)
#     (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Dropout2d(p=0.2, inplace=False)
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Dropout2d(p=0.2, inplace=False)
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.292, Accuracy 53.8): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 27.41it/s]
# test_batch (Avg. Loss 0.932, Accuracy 67.0): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 116.02it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 0.914, Accuracy 67.9): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.93it/s]
# test_batch (Avg. Loss 0.759, Accuracy 73.4): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 123.32it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 0.741, Accuracy 73.9): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.86it/s]
# test_batch (Avg. Loss 0.746, Accuracy 74.4): 100%|███████████████████████████████████| 625/625 [00:07<00:00, 88.78it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 0.619, Accuracy 78.3): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.83it/s]
# test_batch (Avg. Loss 0.724, Accuracy 74.8): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 123.39it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.523, Accuracy 81.7): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.98it/s]
# test_batch (Avg. Loss 0.665, Accuracy 77.0): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 121.03it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.438, Accuracy 84.5): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.24it/s]
# test_batch (Avg. Loss 0.663, Accuracy 77.7): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 120.03it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.371, Accuracy 86.9): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.85it/s]
# test_batch (Avg. Loss 0.661, Accuracy 79.1): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 119.21it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.310, Accuracy 89.0): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.82it/s]
# test_batch (Avg. Loss 0.708, Accuracy 78.6): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 123.91it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.268, Accuracy 90.6): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.84it/s]
# test_batch (Avg. Loss 0.768, Accuracy 77.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 117.97it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.233, Accuracy 91.8): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.84it/s]
# test_batch (Avg. Loss 0.786, Accuracy 78.0): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 112.75it/s]
# test_batch (Avg. Loss 0.788, Accuracy 78.5): 100%|███████████████████████████████████| 834/834 [00:10<00:00, 81.85it/s]
# ==================== Test Results ====================
# Test Accuracy: 78.48
# Test Accuracy: 0.7884648857577938
# ======================================================
# *** Output file ./results\exp4_noL2_with_dropout_lr0.00058.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Dropout2d(p=0.2, inplace=False)
#     (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Dropout2d(p=0.2, inplace=False)
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Dropout2d(p=0.2, inplace=False)
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.291, Accuracy 53.8): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.57it/s]
# test_batch (Avg. Loss 0.922, Accuracy 67.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 117.17it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 0.906, Accuracy 68.4): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.93it/s]
# test_batch (Avg. Loss 0.792, Accuracy 72.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 112.78it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 0.739, Accuracy 73.9): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.64it/s]
# test_batch (Avg. Loss 0.737, Accuracy 74.5): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 116.74it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 0.619, Accuracy 78.0): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.24it/s]
# test_batch (Avg. Loss 0.683, Accuracy 76.7): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 107.63it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.521, Accuracy 81.6): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.92it/s]
# test_batch (Avg. Loss 0.653, Accuracy 77.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 132.81it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.443, Accuracy 84.4): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.47it/s]
# test_batch (Avg. Loss 0.671, Accuracy 78.2): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 125.55it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.372, Accuracy 87.0): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.17it/s]
# test_batch (Avg. Loss 0.692, Accuracy 78.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 129.80it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.313, Accuracy 88.9): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.36it/s]
# test_batch (Avg. Loss 0.686, Accuracy 78.7): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 125.38it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.269, Accuracy 90.5): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.35it/s]
# test_batch (Avg. Loss 0.738, Accuracy 78.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 128.52it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.241, Accuracy 91.5): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.42it/s]
# test_batch (Avg. Loss 0.770, Accuracy 78.2): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 122.19it/s]
# test_batch (Avg. Loss 0.763, Accuracy 78.6): 100%|███████████████████████████████████| 834/834 [00:12<00:00, 65.72it/s]
# ==================== Test Results ====================
# Test Accuracy: 78.64
# Test Accuracy: 0.7629683948104098
# ======================================================
# *** Output file ./results\exp4_noL2_with_dropout_lr0.0006.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Dropout2d(p=0.2, inplace=False)
#     (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Dropout2d(p=0.2, inplace=False)
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Dropout2d(p=0.2, inplace=False)
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.292, Accuracy 53.9): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.48it/s]
# test_batch (Avg. Loss 0.936, Accuracy 66.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 125.28it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 0.903, Accuracy 68.3): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.43it/s]
# test_batch (Avg. Loss 0.778, Accuracy 72.9): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 123.52it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 0.730, Accuracy 74.3): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.52it/s]
# test_batch (Avg. Loss 0.752, Accuracy 74.0): 100%|██████████████████████████████████| 625/625 [00:06<00:00, 102.51it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 0.612, Accuracy 78.4): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.36it/s]
# test_batch (Avg. Loss 0.674, Accuracy 76.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 125.55it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.512, Accuracy 82.0): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.29it/s]
# test_batch (Avg. Loss 0.649, Accuracy 78.1): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 129.48it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.438, Accuracy 84.4): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.30it/s]
# test_batch (Avg. Loss 0.680, Accuracy 77.6): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 122.69it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.368, Accuracy 87.2): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.13it/s]
# test_batch (Avg. Loss 0.673, Accuracy 78.4): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 107.00it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.300, Accuracy 89.5): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.03it/s]
# test_batch (Avg. Loss 0.687, Accuracy 78.8): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 100.01it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.267, Accuracy 90.6): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.25it/s]
# test_batch (Avg. Loss 0.723, Accuracy 78.4): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 125.55it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.224, Accuracy 92.0): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.24it/s]
# test_batch (Avg. Loss 0.813, Accuracy 77.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 110.84it/s]
# test_batch (Avg. Loss 0.806, Accuracy 77.5): 100%|███████████████████████████████████| 834/834 [00:12<00:00, 64.90it/s]
# ==================== Test Results ====================
# Test Accuracy: 77.5
# Test Accuracy: 0.8060311642944438
# ======================================================
# *** Output file ./results\exp4_noL2_with_dropout_lr0.00055.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Dropout2d(p=0.2, inplace=False)
#     (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Dropout2d(p=0.2, inplace=False)
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Dropout2d(p=0.2, inplace=False)
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.293, Accuracy 53.8): 100%|██████████████████████████████████| 850/850 [00:31<00:00, 26.64it/s]
# test_batch (Avg. Loss 0.919, Accuracy 67.6): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 126.98it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 0.909, Accuracy 68.1): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.38it/s]
# test_batch (Avg. Loss 0.759, Accuracy 73.1): 100%|███████████████████████████████████| 625/625 [00:06<00:00, 95.55it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 0.748, Accuracy 73.7): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.30it/s]
# test_batch (Avg. Loss 0.730, Accuracy 75.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 124.00it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 0.636, Accuracy 77.6): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.21it/s]
# test_batch (Avg. Loss 0.654, Accuracy 77.3): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 127.40it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.536, Accuracy 81.1): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.29it/s]
# test_batch (Avg. Loss 0.651, Accuracy 78.0): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 126.31it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.460, Accuracy 83.7): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 26.03it/s]
# test_batch (Avg. Loss 0.682, Accuracy 77.8): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 118.37it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.383, Accuracy 86.4): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.77it/s]
# test_batch (Avg. Loss 0.693, Accuracy 78.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 122.69it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.340, Accuracy 88.1): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.48it/s]
# test_batch (Avg. Loss 0.684, Accuracy 78.7): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 123.15it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.287, Accuracy 89.9): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.51it/s]
# test_batch (Avg. Loss 0.716, Accuracy 79.0): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 121.19it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.256, Accuracy 91.0): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.40it/s]
# test_batch (Avg. Loss 0.754, Accuracy 78.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 106.75it/s]
# test_batch (Avg. Loss 0.775, Accuracy 77.7): 100%|███████████████████████████████████| 834/834 [00:14<00:00, 58.09it/s]
# ==================== Test Results ====================
# Test Accuracy: 77.73
# Test Accuracy: 0.7745896771665198
# ======================================================
# *** Output file ./results\exp4_noL2_with_dropout_lr0.0007.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Dropout2d(p=0.2, inplace=False)
#     (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Dropout2d(p=0.2, inplace=False)
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Dropout2d(p=0.2, inplace=False)
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=150, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.287, Accuracy 54.3): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.50it/s]
# test_batch (Avg. Loss 0.927, Accuracy 67.0): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 108.10it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 0.903, Accuracy 68.2): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.72it/s]
# test_batch (Avg. Loss 0.761, Accuracy 73.3): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 120.59it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 0.727, Accuracy 74.6): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.47it/s]
# test_batch (Avg. Loss 0.723, Accuracy 74.2): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 118.05it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 0.610, Accuracy 78.5): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.68it/s]
# test_batch (Avg. Loss 0.662, Accuracy 77.4): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 117.26it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.508, Accuracy 82.0): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.53it/s]
# test_batch (Avg. Loss 0.657, Accuracy 77.8): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 121.34it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.425, Accuracy 85.1): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.50it/s]
# test_batch (Avg. Loss 0.650, Accuracy 78.4): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 121.36it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.356, Accuracy 87.4): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.37it/s]
# test_batch (Avg. Loss 0.670, Accuracy 78.5): 100%|██████████████████████████████████| 625/625 [00:04<00:00, 125.18it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.294, Accuracy 89.6): 100%|██████████████████████████████████| 850/850 [00:32<00:00, 25.76it/s]
# test_batch (Avg. Loss 0.686, Accuracy 78.8): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 119.85it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.251, Accuracy 91.1): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.01it/s]
# test_batch (Avg. Loss 0.747, Accuracy 78.1): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 122.77it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.218, Accuracy 92.3): 100%|██████████████████████████████████| 850/850 [00:33<00:00, 25.64it/s]
# test_batch (Avg. Loss 0.749, Accuracy 78.5): 100%|██████████████████████████████████| 625/625 [00:05<00:00, 119.46it/s]
# test_batch (Avg. Loss 0.777, Accuracy 78.6): 100%|███████████████████████████████████| 834/834 [00:13<00:00, 63.83it/s]
# ==================== Test Results ====================
# Test Accuracy: 78.56
# Test Accuracy: 0.777422275054168
# ======================================================
# *** Output file ./results\exp4_noL2_with_dropout_lr0.0005.json written

# %%
plot_exp_results('exp4*.json') # plot your experiments results
# Out:
# common config:  {'run_name': 'exp4_withL2_no_dropout_lr0.002', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.002, 'reg': 0.001, 'pool_every': 1, 'hidden_dims': [150], 'ycn': True, 'kw': {}}

# %% [markdown]
# **Answer in your Report:** Why should we use regularization?
# How does the regularization affect the train accuracy and loss? How does it affect the val and test accuracy and loss? What was the best regularization method?
# Summarize this section results in your report.

# %% [markdown]
# ## Summary Up To Here
# **Answer in your Report:** What is your best architecture? what its best accuracy and loss on the test set? Compare your result to assignment 2. How did you mange to improve the model? Summarize this section results in your report.

# %% [markdown]
# ## Use predefined network
# You may want to read about ResNet in this blog:
#
# https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035

# %% [markdown]
# ### 5. Pretrained ResNet50

# %% [markdown]
# Now use ResNet50 with pretraining (use pretrained=True when you load the model) and run this model on cifar 10.
# you will need to change the last linear layer. Tip: `model.fc = nn.Linear(2048, 10)`. you may want to use lower learning rate.

# %%
import torchvision.models as models
# Use meaningful names!
# ====== YOUR CODE: ======
from utils.experiments import save_experiment

model = models.resnet50(pretrained=True).to(device)
model.fc = nn.Linear(2048, 10).to(device)

# pass to the model the optimizer and the loss function
optimizer = optim.Adam(model.parameters(), lr=0.0005)
loss_fn = nn.CrossEntropyLoss()

# create train and test loaders
train_loader = torch.utils.data.DataLoader(ds_train, batch_size=50, shuffle=True)
test_loader = torch.utils.data.DataLoader(ds_test, batch_size=50, shuffle=False)

trainer = training.TorchTrainer(model, loss_fn, optimizer, device)
fit_res = trainer.fit(dl_train=train_loader, dl_val=train_loader, num_epochs=10, checkpoints=None, early_stopping=5, print_every=1, post_epoch_fn=None)

cfg = {"run_name": "exp5_resnet50_with_pretrain", "out_dir": "./results", "seed": seed, "bs_train": 50, "bs_test": 12, "batches": 10, "epochs": 10, "early_stopping": 5, "checkpoints": None, "lr": lr, "reg": 0.001, "filters_per_layer": {}, "layers_per_block": {}, "pool_every": 1, "hidden_dims": {
}, "ycn": True, "kw": {}} # hard coded to make it savable

test_epoch_result = trainer.test_epoch(test_loader)
print("==================== Test Results ====================")
print(f"Train Accuracy: {test_epoch_result.accuracy}")
print(f"Test Accuracy: {np.mean(test_epoch_result.losses)}")
print("======================================================")
save_experiment('exp5_resnet50_with_pretrain', './results', cfg, fit_res)
# ========================
# Out:
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 0.875, Accuracy 70.6): 100%|████████████████████████████████| 1000/1000 [03:27<00:00,  4.81it/s]
# test_batch (Avg. Loss 0.524, Accuracy 82.5): 100%|█████████████████████████████████| 1000/1000 [00:46<00:00, 21.28it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 0.595, Accuracy 80.2): 100%|████████████████████████████████| 1000/1000 [03:27<00:00,  4.81it/s]
# test_batch (Avg. Loss 0.546, Accuracy 82.5): 100%|█████████████████████████████████| 1000/1000 [00:47<00:00, 21.27it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 0.477, Accuracy 84.0): 100%|████████████████████████████████| 1000/1000 [03:27<00:00,  4.81it/s]
# test_batch (Avg. Loss 0.292, Accuracy 90.5): 100%|█████████████████████████████████| 1000/1000 [00:47<00:00, 21.27it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 0.378, Accuracy 87.4): 100%|████████████████████████████████| 1000/1000 [03:27<00:00,  4.82it/s]
# test_batch (Avg. Loss 0.255, Accuracy 91.2): 100%|█████████████████████████████████| 1000/1000 [00:46<00:00, 21.28it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 0.316, Accuracy 89.5): 100%|████████████████████████████████| 1000/1000 [03:28<00:00,  4.79it/s]
# test_batch (Avg. Loss 0.332, Accuracy 88.9): 100%|█████████████████████████████████| 1000/1000 [00:47<00:00, 21.18it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 0.285, Accuracy 90.4): 100%|████████████████████████████████| 1000/1000 [03:28<00:00,  4.79it/s]
# test_batch (Avg. Loss 0.148, Accuracy 95.0): 100%|█████████████████████████████████| 1000/1000 [00:47<00:00, 21.18it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 0.197, Accuracy 93.3): 100%|████████████████████████████████| 1000/1000 [03:28<00:00,  4.81it/s]
# test_batch (Avg. Loss 0.126, Accuracy 95.7): 100%|█████████████████████████████████| 1000/1000 [00:47<00:00, 21.26it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.169, Accuracy 94.3): 100%|████████████████████████████████| 1000/1000 [03:27<00:00,  4.81it/s]
# test_batch (Avg. Loss 0.186, Accuracy 93.8): 100%|█████████████████████████████████| 1000/1000 [00:47<00:00, 21.24it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.170, Accuracy 94.4): 100%|████████████████████████████████| 1000/1000 [03:27<00:00,  4.81it/s]
# test_batch (Avg. Loss 0.107, Accuracy 96.8): 100%|█████████████████████████████████| 1000/1000 [00:46<00:00, 21.28it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.136, Accuracy 95.5): 100%|████████████████████████████████| 1000/1000 [03:27<00:00,  4.81it/s]
# test_batch (Avg. Loss 0.075, Accuracy 97.6): 100%|█████████████████████████████████| 1000/1000 [00:47<00:00, 21.27it/s]
# test_batch (Avg. Loss 0.686, Accuracy 82.0): 100%|███████████████████████████████████| 200/200 [00:09<00:00, 21.29it/s]
# ==================== Test Results ====================
# Train Accuracy: 82.05
# Test Accuracy: 0.6862683292478323
# ======================================================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [46], line 26
#      24 print(f"Test Accuracy: {np.mean(test_epoch_result.losses)}")
#      25 print("======================================================")
# ---> 26 save_experiment('exp5_resnet50', './results', locals(), fit_res)
#
# File ~\Desktop\final_project\utils\experiments.py:100, in save_experiment(run_name, out_dir, config, fit_res)
#      98 os.makedirs(out_dir, exist_ok=True)
#      99 with open(output_filename, 'w') as f:
# --> 100     json.dump(output, f, indent=2)
#     102 print(f'*** Output file {output_filename} written')
#
# File ~\anaconda3\envs\gpu\lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~\anaconda3\envs\gpu\lib\json\encoder.py:431, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     429     yield from _iterencode_list(o, _current_indent_level)
#     430 elif isinstance(o, dict):
# --> 431     yield from _iterencode_dict(o, _current_indent_level)
#     432 else:
#     433     if markers is not None:
#
# File ~\anaconda3\envs\gpu\lib\json\encoder.py:405, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     403         else:
#     404             chunks = _iterencode(value, _current_indent_level)
# --> 405         yield from chunks
#     406 if newline_indent is not None:
#     407     _current_indent_level -= 1
#
# File ~\anaconda3\envs\gpu\lib\json\encoder.py:405, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     403         else:
#     404             chunks = _iterencode(value, _current_indent_level)
# --> 405         yield from chunks
#     406 if newline_indent is not None:
#     407     _current_indent_level -= 1
#
# File ~\anaconda3\envs\gpu\lib\json\encoder.py:438, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     436         raise ValueError("Circular reference detected")
#     437     markers[markerid] = o
# --> 438 o = _default(o)
#     439 yield from _iterencode(o, _current_indent_level)
#     440 if markers is not None:
#
# File ~\anaconda3\envs\gpu\lib\json\encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type module is not JSON serializable

# %%
# same as above but with pretrained=False
import torchvision.models as models
# Use meaningful names!
# ====== YOUR CODE: ======
from utils.experiments import save_experiment

model = models.resnet50(pretrained=False).to(device)
model.fc = nn.Linear(2048, 10).to(device)

# pass to the model the optimizer and the loss function
optimizer = optim.Adam(model.parameters(), lr=0.0005)
loss_fn = nn.CrossEntropyLoss()

# create train and test loaders
train_loader = torch.utils.data.DataLoader(ds_train, batch_size=50, shuffle=True)
test_loader = torch.utils.data.DataLoader(ds_test, batch_size=50, shuffle=False)

trainer = training.TorchTrainer(model, loss_fn, optimizer, device)
fit_res = trainer.fit(dl_train=train_loader, dl_val=train_loader, num_epochs=10, checkpoints=None, early_stopping=5, print_every=1, post_epoch_fn=None)

cfg = {"run_name": "exp5_resnet50_without_pretrain", "out_dir": "./results", "seed": seed, "bs_train": 50, "bs_test": 12, "batches": 10, "epochs": 10, "early_stopping": 5, "checkpoints": None, "lr": lr, "reg": 0.001, "filters_per_layer": {}, "layers_per_block": {}, "pool_every": 1, "hidden_dims": {
}, "ycn": True, "kw": {}} # hard coded to make it savable

test_epoch_result = trainer.test_epoch(test_loader)
print("==================== Test Results ====================")
print(f"Train Accuracy: {test_epoch_result.accuracy}")
print(f"Test Accuracy: {np.mean(test_epoch_result.losses)}")
print("======================================================")
save_experiment('exp5_resnet50_without_pretrain', './results', cfg, fit_res)
# ========================
# Out:
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.808, Accuracy 36.6): 100%|████████████████████████████████| 1000/1000 [01:30<00:00, 11.05it/s]
# test_batch (Avg. Loss 1.512, Accuracy 45.9): 100%|█████████████████████████████████| 1000/1000 [00:30<00:00, 32.64it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.442, Accuracy 49.0): 100%|████████████████████████████████| 1000/1000 [01:30<00:00, 10.90it/s]
# test_batch (Avg. Loss 1.226, Accuracy 56.7): 100%|█████████████████████████████████| 1000/1000 [00:30<00:00, 32.86it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.396, Accuracy 51.9): 100%|████████████████████████████████| 1000/1000 [01:30<00:00, 11.08it/s]
# test_batch (Avg. Loss 1.346, Accuracy 52.0): 100%|█████████████████████████████████| 1000/1000 [00:30<00:00, 32.78it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.315, Accuracy 55.3): 100%|████████████████████████████████| 1000/1000 [01:30<00:00, 11.07it/s]
# test_batch (Avg. Loss 1.224, Accuracy 59.0): 100%|█████████████████████████████████| 1000/1000 [00:30<00:00, 32.79it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.210, Accuracy 58.6): 100%|████████████████████████████████| 1000/1000 [01:30<00:00, 11.06it/s]
# test_batch (Avg. Loss 1.097, Accuracy 60.8): 100%|█████████████████████████████████| 1000/1000 [00:30<00:00, 32.59it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.080, Accuracy 63.0): 100%|████████████████████████████████| 1000/1000 [01:30<00:00, 11.06it/s]
# test_batch (Avg. Loss 3.951, Accuracy 47.2): 100%|█████████████████████████████████| 1000/1000 [00:30<00:00, 32.68it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.019, Accuracy 65.5): 100%|████████████████████████████████| 1000/1000 [01:30<00:00, 11.10it/s]
# test_batch (Avg. Loss 1.329, Accuracy 55.2): 100%|█████████████████████████████████| 1000/1000 [00:30<00:00, 32.67it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.973, Accuracy 66.7): 100%|████████████████████████████████| 1000/1000 [01:30<00:00, 11.08it/s]
# test_batch (Avg. Loss 0.856, Accuracy 70.0): 100%|█████████████████████████████████| 1000/1000 [00:30<00:00, 32.75it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.954, Accuracy 67.9): 100%|████████████████████████████████| 1000/1000 [01:30<00:00, 11.07it/s]
# test_batch (Avg. Loss 1.459, Accuracy 60.7): 100%|█████████████████████████████████| 1000/1000 [00:30<00:00, 32.65it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.957, Accuracy 67.4): 100%|████████████████████████████████| 1000/1000 [01:30<00:00, 11.05it/s]
# test_batch (Avg. Loss 0.721, Accuracy 74.3): 100%|█████████████████████████████████| 1000/1000 [00:30<00:00, 32.78it/s]
# test_batch (Avg. Loss 0.909, Accuracy 68.2): 100%|███████████████████████████████████| 200/200 [00:06<00:00, 32.63it/s]
# ==================== Test Results ====================
# Train Accuracy: 68.22
# Test Accuracy: 0.9086947128176689
# ======================================================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [66], line 29
#      27 print(f"Test Accuracy: {np.mean(test_epoch_result.losses)}")
#      28 print("======================================================")
# ---> 29 save_experiment('exp5_resnet50_without_pretrain', './results', locals(), fit_res)
#
# File ~\Desktop\final_project\utils\experiments.py:100, in save_experiment(run_name, out_dir, config, fit_res)
#      98 os.makedirs(out_dir, exist_ok=True)
#      99 with open(output_filename, 'w') as f:
# --> 100     json.dump(output, f, indent=2)
#     102 print(f'*** Output file {output_filename} written')
#
# File ~\anaconda3\envs\gpu\lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~\anaconda3\envs\gpu\lib\json\encoder.py:431, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     429     yield from _iterencode_list(o, _current_indent_level)
#     430 elif isinstance(o, dict):
# --> 431     yield from _iterencode_dict(o, _current_indent_level)
#     432 else:
#     433     if markers is not None:
#
# File ~\anaconda3\envs\gpu\lib\json\encoder.py:405, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     403         else:
#     404             chunks = _iterencode(value, _current_indent_level)
# --> 405         yield from chunks
#     406 if newline_indent is not None:
#     407     _current_indent_level -= 1
#
# File ~\anaconda3\envs\gpu\lib\json\encoder.py:405, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     403         else:
#     404             chunks = _iterencode(value, _current_indent_level)
# --> 405         yield from chunks
#     406 if newline_indent is not None:
#     407     _current_indent_level -= 1
#
# File ~\anaconda3\envs\gpu\lib\json\encoder.py:438, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     436         raise ValueError("Circular reference detected")
#     437     markers[markerid] = o
# --> 438 o = _default(o)
#     439 yield from _iterencode(o, _current_indent_level)
#     440 if markers is not None:
#
# File ~\anaconda3\envs\gpu\lib\json\encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type module is not JSON serializable

# %%
plot_exp_results('exp5_resnet50*.json') # plot your experiments results
# Out:
# common config:  {'run_name': 'exp5_resnet50_without_pretrain', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.00058, 'reg': 0.001, 'pool_every': 1, 'hidden_dims': {}, 'ycn': True, 'kw': {}}

# %% [markdown]
# **Answer in your Report:** What was the pretrained ResNet50 accuracy and loss? Is it overfit/underfit/well-fit the data? Has it got better accuracy than the non-pretrained ResNet? Summarize this section results in your report.

# %% [markdown]
# ### 5. Summeraize Bert and ViT blogs
# Read these two blogs:
# 1. https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270
# 2. https://towardsdatascience.com/what-are-vision-transformers-and-how-are-they-important-for-general-purpose-learning-edd008545e9e
#
# Summeraize the bert and ViT information from these two blogs in hebrew.

# %% [markdown]
# ## Project Summary
# **Answer in your Report:** Write a short summerization of your attempts. What worked for you? which architecture and hyperparameters led to the best preformance?
